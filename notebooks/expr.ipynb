# %%
# !bash Track2/run/feats_aug_eng.sh
# Out:
# /notebooks/Track2/configs/local_aggr/feats_aug_eng.yaml
# wandb: Currently logged in as: quangminhdinh. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.14.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /notebooks/wandb/run-20230325_032814-10zy0s9o
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dual-text-cat-aggr-f-feats_aug_eng
# wandb: ⭐️ View project at https://wandb.ai/quangminhdinh/local_aggr
# wandb: 🚀 View run at https://wandb.ai/quangminhdinh/local_aggr/runs/10zy0s9o
# ====> load config from feats_aug_eng
# True
# ====> set seed 42
# FEAT_ENG: True
# ====> /datasets/aicitychallenge2023/train.json data load, ids: 2055
# ====> /datasets/aicitychallenge2023/test-tracks.json data load, ids: 10424
# ====> SSM Siamese Enhanced Collator:
# ====> Using visual backbone: SiameseDualEnhancedEncoder
# ...

# %%
# REMEMBER TO RECONFIG TEST AND GET_SUBMIT BEFORE GENERATING JSON
# !bash Track2/run/dual_aggr.sh
# Out:
# ====> load config from dual_aggr
# wandb: Currently logged in as: quangminhdinh. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.14.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /notebooks/wandb/run-20230322_062600-3b3vcn5l
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dual-text-cat-aggr-f-f
# wandb:  View project at https://wandb.ai/quangminhdinh/local_aggr
# wandb:  View run at https://wandb.ai/quangminhdinh/local_aggr/runs/3b3vcn5l
# ====> set seed 42
# ====> /datasets/aicitychallenge2023/train.json data load, ids: 2055
# ====> /datasets/aicitychallenge2023/test-tracks.json data load, ids: 10424
# ====> SSM Siamese Enhanced Collator:
# ====> Using visual backbone: SiameseDualEnhancedEncoder
# Loaded pretrained weights for efficientnet-b2
# Loaded pretrained weights for efficientnet-b2
# ...

# %%
# !bash Track2/run/submit.sh
# Out:
# 184 184
# /notebooks/Track2/configs/local_aggr/feats_aug_eng.yaml
# wandb: Currently logged in as: quangminhdinh. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.14.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.4
# wandb: Run data is saved locally in /notebooks/wandb/run-20230325_190919-2yjv078u
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dual-text-cat-aggr-f-feats_aug_eng
# wandb: ⭐️ View project at https://wandb.ai/quangminhdinh/local_aggr
# wandb: 🚀 View run at https://wandb.ai/quangminhdinh/local_aggr/runs/2yjv078u
# ====> load config from feats_aug_eng
# FEAT_ENG: True
# /notebooks/Track2/configs/local_aggr/dual_aggr.yaml
# s3://aicitychallenge2023/extracted_feats/dual_aggr/img_lang_feat_checkpoint_best.pth
# ====> Generating s3://aicitychallenge2023/extracted_feats/dual_aggr/img_lang_feat_checkpoint_best.pth
# ...

# %%
# !bash Track2/run/dual_baseline_aug1.sh
# Out:
# ====> load config from dual_baseline_aug1
# ====> set seed 42
# ====> /datasets/aicitychallenge2023/train.json data load, ids: 2055
# ====> /datasets/aicitychallenge2023/test-tracks.json data load, ids: 10424
# ====> SSM Siamese Collator:
# ====> Using visual backbone: SiameseLocalandMotionModelBIG_DualTextCat
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b2-8bb594d6.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b2-8bb594d6.pth
# 100%|███████████████████████████████████████| 35.1M/35.1M [00:00<00:00, 154MB/s]
# Loaded pretrained weights for efficientnet-b2
# Loaded pretrained weights for efficientnet-b2
# ...
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight']
# ...

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# agate==1.6.0
# agate-dbf==0.2.0
# agate-excel==0.2.3
# agate-sql==0.5.2
# aiohttp==3.8.3
# aiosignal==1.3.1
# anyio==3.6.2
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asttokens==2.2.1
# astunparse==1.6.3
# async-timeout==4.0.2
# attrs==18.2.0
# awscli==1.25.91
# Babel==2.11.0
# backcall==0.2.0
# beautifulsoup4==4.11.1
# bleach==6.0.0
# blis==0.7.9
# boto3==1.24.90
# botocore==1.27.90
# cached-property==1.5.2
# cachetools==5.3.0
# catalogue==2.0.8
# certifi==2019.11.28
# cffi==1.15.1
# chardet==3.0.4
# charset-normalizer==2.1.1
# chex==0.1.5
# click==8.1.3
# click-completion==0.5.2
# click-didyoumean==0.3.0
# click-help-colors==0.9.1
# cloudpickle==2.2.0
# colorama==0.4.3
# colorlog==6.7.0
# comm==0.1.2
# confection==0.0.4
# contourpy==1.0.7
# csvkit==1.0.2
# cycler==0.11.0
# cymem==2.0.7
# Cython==0.29.32
# datasets==2.4.0
# dbfread==2.0.7
# dbus-python==1.2.16
# debugpy==1.6.6
# decorator==5.1.1
# defusedxml==0.7.1
# dill==0.3.5.1
# dm-tree==0.1.8
# ...
